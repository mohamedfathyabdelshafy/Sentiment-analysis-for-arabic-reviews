# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import itertools
import csv
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem.isri import ISRIStemmer
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble.forest import RandomForestClassifier
from sklearn.model_selection import KFold

# %%
files = ['HTL.csv']

# %%
def prepareDatasetes(files):
    sentences = []
    
    for file_name in files:
        file = open(file_name,"rt", encoding="utf-8")
        reviews = csv.reader(file)
        for text,polarity in reviews:
            sentences.append([text,polarity])
        
        df = DataFrame(sentences, columns = ['text','polarity'])
        file.close()
        return df

# %%
reviews = prepareDatasetes(files)

# %%
import mysql.connector
from mysql.connector import errorcode, connect

# %%
def connectMysql():
    try:
        cnn = connect(
        user ='root',
            password='',
            host='localhost',
            database='test')
        return cnn
    except mysql.connector.Error as e:
        if e.errno == errorcode.ER_ACCESS_DENIED_ERROR:
            print ("Access denied")
        elif e.errno == errorcode.ER_BAD_DB_ERROR:
            print ("Database doesn't exist")
        else:
            print [e]

# %%
def createTable(sql):
    try:
        cnn = connectMysql()
        cursor = cnn.cursor()
        cursor.execute(sql)
    except:
        cnn.rollback()
    cnn.close()

# %%
sql = "DROP TABLE IF EXISTS REVIEWS; CREATE TABLE REVIEWS (TEXT TEXT NOT NULL, POLARITY INT(10))"
createTable(sql)

# %%
def insertData(text, polarity):
    try:
        cnn = connectMysql()
        cursor = cnn.cursor()
        cursor.execute("INSERT INTO `REVIEWS` VALUES ('%s', '%s')" % (text, polarity))
        cursor.commit()
    except:
        cnn.rollback()
    cnn.close()

# %%
#reviews

# %%
for index, (text, polarity) in reviews.iterrows():
    insertData(text, polarity)

# %%
def getData(sql):
    cnn = connectMysql()
    cursor = cnn.cursor()
    cursor.execute(sql)
    reviews = DataFrame(cursor.fetchall())
    reviews.rename(columns={0:'text', 1:'label'}, inplace=True)
    cursor.close()
    cnn.close()
    return reviews

# %%
sql = "SELECT * FROM `REVIEWS`"
reviews = getData(sql)
len(reviews)
# Out:
# 13358

# %%
reviews
# Out:
#                                                     text  label
# 0      المكان الذي يمكنك فيه مراجعة الذات والتفكر هو ...      1
# 1      أسوأ فندق أقمت فيه على الإطلاق  \nيستغرق تسجيل...     -1
# 2      فندق جميل مع سوء الإدارة والخدمات.  \nمن الخار...     -1
# 3      فندق جميل، منظر رائع من بركة السباحة (على السط...      1
# 4      مكان لطيف وهادئ بعيدًا عن الزحام  \nعثرت على ه...      1
# 5      راقي و كلاسيكي"  \nفندق كبير مصمم بفن الديكور ...      1
# 6      تحذير للرجال الذي يحبون تناول بعض البيرة ليلاً...      1
# 7      فندق رائع  \nبعد 4 أيام قضيناها في ليسبوا، وصل...      1
# 8      ساحر  \nإذا كنت تتوق إلى تجربة فريدة، عليك بتج...      1
# 9      هناك بعض الإحباطات ولكن الغرف كانت رائعة والمو...      1
# 10     لطيف للغاية...!  \n-الموقع منقطع النظير-فريق ا...      1
# 11     فندق رائع جداً وأنصح به \nفندق فخم وحديث كبير ...      1
# 12     فندق رائع! فريق عمل ودود وإفطار جيد  \nليس لدي...      1
# 13     أسوأ خدمة عملاء  \nالفندق نفسه جميل. فيما عدا ...     -1
# 14     فندق من فئة نجمة واحدة يصنف بأربعة ؟  \nالفندق...     -1
# 15     فندق رائع  \nعدنا للتو من إقامة لمدة ثمانية أي...      1
# 16     طعام رديء  \nهذا الفندق تحتاج إلى تغيير في الإ...     -1
# 17     فندق رائع وموقع رائع.  \nأقمنا في هذا الفندق ا...      1
# 18     مكان رائع ولطيف  \nذهبت الى هناك في نهاية اغسط...      1
# 19     "رهيب"  \nهذا الفندق لم يشهد أي طبقة من الطلاء...     -1
# 20     العائلات عليكم توخي الحذر  \nإذا كان ستسافر مع...     -1
# 21     قيمة ممتازة للمال! لا يمكنني أن أفهم التقييمات...      1
# 22     جيد بشكل مذهل!  \nلقد ذهبنا في أسبوع عطلة عائل...      1
# 23     لا بأس به ولكن ذو لمسة رخيصة  \nرجعت ظهر اليوم...     -1
# 24     مخيب للآمال - لا تحصل إلا على ما تدفع ثمنه!  \...     -1
# 25     أفضل عطلة خلال 10سنوات،  \nنحن عائلة من وارينغ...      1
# 26     فهو حظ مثل حظ القرعة أن تحصل على شقة جيدة!!!! ...      1
# 27     4 أيام سيئة  \nتجهيزات هذا الفندق ليست بدرجة 4...     -1
# 28     أكثر مما أملنا به!  \nقام ثومسونز بنقلنا إلى ف...      1
# 29     ربما يكون أفضل في فصل الصيف.  \nمكثت بنصف إقام...     -1
# ...                                                  ...    ...
# 13328  تقييمات الزوار على المدى الطويل - مخاوف أمنية ...      1
# 13329  أفضل سر مخفي على الإطلاق ... \nهذا الفندق هو أ...      1
# 13330  مكان رائع للإقامة في YMCA Fort Canning Lodge \...      1
# 13331  فندق ذو موقع ممتاز، يتناسب مع كافة أفراد العائ...      1
# 13332  إقامة ممتازة \nموقع الفندق مريح ويبعد مسافة قر...      1
# 13333  لقد تمت زيارته من قبل الشخصيات الملكية والنبيل...      1
# 13334  مستوى خدمة جيد للغاية من الموظفين وكذلك المدير...      1
# 13335  توقع غير المتوقع!  \nالموقع - غرفة جيدة وصغيرة...     -1
# 13336  لمسة بحرية  \nجميل وظريفة، فندق تقليدي في المد...      1
# 13337  الأمانة هي أفضل سياسة  \n20 أغسطس 2011. أقمت ف...      1
# 13338  ببساطة رائع  \nاستمتعت 3 ليال في هذا الفندق ال...      1
# 13339  فندق أكثر من رائع \nبصراحه اول مرة نسكن فى فند...      1
# 13340  المملكة العربية السعودية \nالفندق لايستحق ان ي...     -1
# 13341  لا توجد نوافذ في الغرف وهي حارة جداً!  \nأقمت ...     -1
# 13342  فندق وسط المنطقة \nفندق ذو أربعة نجوم الا ان ا...     -1
# 13343  كما في منزلك.....  \nكما في منزلك... سوف تقيم ...      1
# 13344  مكان ممتاز للإقامة  \nأقمنا ليلتين فقط، لكن كل...      1
# 13345  موظفون بشعون وغرفة بشعة. انجُ بنفسك، ابتعد. يا...     -1
# 13346  بصراحة، حتى بعد بناء...  \nبصراحة، حتى بعد بنا...      1
# 13347  عافية وصحة لروحك في أجواء مريحة.  \nإذا كنت تح...      1
# 13348  هدئ أعصابك.... مكان جيد للاسترخاء  \nالفندق عل...      1
# 13349  ملائم للمغادرة صباحًا أو الوصول المتأخر جدًا. ...      1
# 13350  رخيص وسيئ.  \nالسجن هو الكلمة التي تتبادر إلى ...     -1
# 13351  سعر رائع وموقع جيد للمواصلات إذا كنت تستخدم ال...      1
# 13352  إفطار جيد + نظيف  \nأقمت هنا لليلة واحدة مع ال...      1
# 13353  عطلة رائعة في نهاية الأسبوع  \nإقامة جميلة ومر...      1
# 13354  قريب من كل شي \nجميل وهادي وكل شي حولك حتي الم...      1
# 13355  فندق رائع وممتاز \nلقد نزلت بتاريخ 1/12/2013 ف...      1
# 13356  احقر مكان على وجه الارض \nانصح كل الذين يقومون...     -1
# 13357  ضيق جدا \nالفندق ضيق جدا من حيث مساحة الغرف وا...      1
#
# [13358 rows x 2 columns]

# %%
def normalize(text):
    text = re.sub("[إأٱآا]", "ا", text)
    text = re.sub("ى", "ي", text)
    text = re.sub("ؤ", "ء", text)
    text = re.sub("ئ", "ء", text)
    text = re.sub("[a-zA-Z0-9_]",'',text)
    noise = re.compile(""" ّ    | # Tashdid
                             َ    | # Fatha
                             ً    | # Tanwin Fath
                             ُ    | # Damma
                             ٌ    | # Tanwin Damm
                             ِ    | # Kasra
                             ٍ    | # Tanwin Kasr
                             ْ    | # Sukun
                             ـ     # Tatwil/Kashida
                         """, re.VERBOSE)
    text = re.sub(noise, '', text)
    return(text)

# %%
normalize("9 hh بسم الله الرحمن الرحيم")
# Out:
# '  بسم الله الرحمن الرحيم'

# %%
def stopWordRomve(text):
    ar_stop_list = open("list.txt","r",encoding="utf8")
    stop_words = ar_stop_list.read().split('\n')
    needed_words = []
    words = word_tokenize(text)
    for w in words:
        if w not in (stop_words):
            needed_words.append(w)
    filtered_sentence = " ".join(needed_words)
    ar_stop_list.close()
    return filtered_sentence

# %%
stopWordRomve("بسم الله الرحمن الرحيم")
# Out:
# 'بسم الله الرحمن الرحيم'

# %%
def stemming(text):
    st = ISRIStemmer()
    stemmed_words = []
    words = word_tokenize(text)
    for w in words:
        stemmed_words.append(st.stem(w))
    stemmed_sentence = " ".join(stemmed_words)
    return stemmed_sentence

# %%
print (stemming("بسم الله الرحمن الرحيم"))
# Out:
# بسم الل رحم رحم

# %%
def prepareDataSets(reviews):
    sentences = []
    for index, r in reviews.iterrows():
        text = stopWordRomve(r['text'])
        text = normalize(r['text'])
        text = stemming(r['text'])
        if r['label'] == -1:
            sentences.append([text,'neg'])
        elif r['label'] == 1:
            sentences.append([text,'pos'])
        
    def_sentences = DataFrame(sentences, columns=['text','label'])
    return def_sentences

# %%
preprocessed_reviews = prepareDataSets(reviews)
preprocessed_reviews
# Out:
#                                                     text label
# 0      كان الذي يمك فيه رجع ذات فكر هو كوكروبيت، غنا ...   pos
# 1      اسأ ندق اقم فيه على طلق غرق سجل وصل حلي 30 دقي...   neg
# 2      ندق جمل مع سوء درة خدم . من خرج بدا مبشرا، لكن...   neg
# 3      ندق جميل، نظر رئع من برك سبح ( على سطح ) ! ! !...   pos
# 4      كان لطف هدئ بعد عن زحم عثر على هذا كان عن طرق ...   pos
# 5      رقي و كلس '' ندق كبر صمم بفن ديكور جمل ارت ديك...   pos
# 6      حذر رجل الذي يحب نول بعض بير ليل ! شيء وحد اود...   pos
# 7      ندق رئع بعد 4 ايم قضن في بو، وصل اخر الى نزل ....   pos
# 8      سحر اذا كنت تتق الى جرب ريدة، علك جرب ندق است ...   pos
# 9      هناك بعض حبط ولكن غرف كانت رئع وقع لا يمكن نفس...   pos
# 10     لطف غية ... ! -الموقع قطع نظير-فريق عمل ودد غي...   pos
# 11     ندق رئع جدا أنصح به ندق فخم حدث كبر جدا ريح جد...   pos
# 12     ندق رئع ! فرق عمل ودد إفطار جيد ليس لدي سوى شي...   pos
# 13     اسأ خدم عملاء ندق نفس جمل . فيم عدا ذلك، ليس ل...   neg
# 14     ندق من فئة نجم وحد صنف أربع ؟ ندق قدم جد، خدم ...   neg
# 15     ندق رئع عدن لتو من قمة لمد ثمن ايم في كلب شينو...   pos
# 16     طعم ردء هذا ندق حاج الى غير في درة حيث ان طعم ...   neg
# 17     ندق رئع وقع رئع . اقم في هذا ندق جمل في فتر من...   pos
# 18     كان رئع لطف ذهب الى هناك في نهي غسطس وبد مبر و...   pos
# 19     `` رهب '' هذا ندق لم شهد اي طبق من طلء او اي ح...   neg
# 20     عئل علي توخ حذر اذا كان سفر مع عئل لا ذهب الى ...   neg
# 21     قيم متز مال ! لا يمك ان فهم قيم سيئ . عطل كانت...   pos
# 22     جيد شكل ذهل ! لقد ذهب في سبع عطل عئل لهذ شقق، ...   pos
# 23     لا بأس به ولكن ذو لمس رخص رجع ظهر اليوم من هذه...   neg
# 24     خيب امل - لا حصل الا على ما دفع ثمن ! نزل في و...   neg
# 25     فضل عطل خلل 10سنوات، نحن عئل من رينغ سفر الى غ...   pos
# 26     فهو حظ مثل حظ قرع ان حصل على شقة جيد ! ! ! ! ه...   pos
# 27     4 ايم سيئ جهز هذا ندق ليس درج 4 نجم . لم تقي ن...   neg
# 28     كثر مما امل به ! قام ثومسونز نقل الى فيل الب ب...   pos
# 29     ربم يكون فضل في فصل صيف . كثت نصف قمة لمد 3 اب...   neg
# ...                                                  ...   ...
# 13328  قيم زور على مدى طول - خاف مني مرحبا، اسم كيث ي...   pos
# 13329  فضل سر خفي على طلق ... هذا ندق هو فضل سر خفي ....   pos
# 13330  كان رئع قمة في YMCA Fort Canning Lodge عبر YWC...   pos
# 13331  ندق ذو وقع ممتاز، نسب مع كفة فرد عائلة، وجد عل...   pos
# 13332  قمة متز وقع ندق ريح بعد ساف قرب عن كلر كوي حيث...   pos
# 13333  لقد تمت زير من قبل شخص لكة نبل اآآ ... . ندق ر...   pos
# 13334  ستى خدم جيد غية من وظف كذل دير وكان وظف الذين ...   pos
# 13335  وقع غير توقع ! وقع - غرف جيد صغر - حشر شكل لا ...   neg
# 13336  لمس بحر جمل ظريفة، ندق قلد في دين ارخ قدم . سأ...   pos
# 13337  منة هي فضل سيس 20 غسطس 2011 . اقم في دمر لمد 6...   pos
# 13338  بسط رئع متع 3 ليل في هذا ندق سطر . حصل على غرف...   pos
# 13339  ندق كثر من رئع صرح اول مرة نسك فى ندق 3 نجم بم...   pos
# 13340  ملك عرب سعد ندق سحق ان يكون من فئة ربع نجم يجب...   neg
# 13341  لا وجد نفذ في غرف وهي حرة جدا ! اقم في هذا نزل...   neg
# 13342  ندق وسط نطق ندق ذو ربع نجم الا ان خدم لا رقى ا...   neg
# 13343  كما في زلك ... .. كما في زلك ... سوف تقم في هي...   pos
# 13344  كان متز قمة اقم ليل قط، لكن كل شيء كان رائعا، ...   pos
# 13345  وظف بشع غرف بشع . انج سك، بعد . يا له، بعد ! !...   neg
# 13346  صراحة، حتى بعد بنء ... صراحة، حتى بعد بنء بنى ...   pos
# 13347  عفي وصح لرح في جوء ريح . اذا كنت تحب بحر وتل ش...   pos
# 13348  هدئ عصب ... . كان جيد رخء ندق على بعد 10 دقق م...   pos
# 13349  لئم غدر صبح او وصل تأخر جدا . يجب : وقع رائق، ...   pos
# 13350  رخص وسئ . سجن هو كلم التي بدر الى ذهن فقط ، اع...   neg
# 13351  سعر رئع وقع جيد وصل اذا كنت خدم ذكر يوم . كان ...   pos
# 13352  فطر جيد + نظف اقم هنا يلة وحد مع سيد بعض صدقاء...   pos
# 13353  عطل رئع في نهي سبع قمة جمل ريح في ندق سود انق ...   pos
# 13354  قرب من كل شي جمل وهد وكل شي حول حتي وقف هدي صل...   pos
# 13355  ندق رئع متز لقد نزل ارخ 1/12/2013 في هذا ندق و...   pos
# 13356  حقر كان على وجه ارض نصح كل الذين يقم صفح ندق ع...   neg
# 13357  ضيق جدا ندق ضيق جدا من حيث ساح غرف حمم اما كنه...   pos
#
# [13358 rows x 2 columns]

# %%
def featureExtraction(data):
    vectorizer = TfidfVectorizer(min_df=10, max_df=0.75, ngram_range=(1,3))
    tfidf_data = vectorizer.fit_transform(data)
    return tfidf_data

# %%
def learning(clf, x, y):
      
    x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=.2, random_state=42)
   
    classifer = clf()
    classifer.fit(x_train, y_train)
    predict = sklearn.model_selection.cross_val_predict(classifer, x_test, y_test, cv=10)
    
    scores = sklearn.model_selection.cross_val_score(classifer, x_test, y_test, cv=10)
    print (scores)
    print ("Accurecy of %s: %0.2f (+/- %0.2f)" % (classifer, scores.mean(), scores.std() *2))
    print (classification_report(y_test, predict))

# %%
def main(clf):
    reviews = getData("SELECT * FROM `REVIEWS`")
    preprocessed_reviews = prepareDataSets(reviews)
    data, target = preprocessed_reviews['text'], preprocessed_reviews['label']
    tfidf_data = featureExtraction(data)
    learning(clf,tfidf_data, target)

# %%
#clfs = [MultinomialNB, BernoulliNB, LogisticRegression, SGDClassifier, SVC, LinearSVC, DecisionTreeClassifier, RandomForestClassifier]

# %%
clfs = [MultinomialNB]

# %%
import warnings
warnings.filterwarnings('ignore', message='the matrix subclass is not the recommended way')

with warnings.catch_warnings():
    warnings.filterwarnings("ignore")

from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

# %%
for clf in clfs:
    main(clf)
# Out:
# [0.80597015 0.80597015 0.80597015 0.80898876 0.80898876 0.80898876
#  0.8164794  0.80898876 0.80898876 0.81203008]
# Accurecy of MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True): 0.81 (+/- 0.01)
#               precision    recall  f1-score   support
#
#          neg       1.00      0.01      0.01       513
#          pos       0.81      1.00      0.89      2159
#
#    micro avg       0.81      0.81      0.81      2672
#    macro avg       0.90      0.50      0.45      2672
# weighted avg       0.85      0.81      0.72      2672

# %%
clfs = [BernoulliNB]
for clf in clfs:
    main(clf)
# Out:
# [0.86567164 0.85820896 0.87313433 0.83146067 0.82397004 0.8576779
#  0.86516854 0.85018727 0.83146067 0.84586466]
# Accurecy of BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True): 0.85 (+/- 0.03)
#               precision    recall  f1-score   support
#
#          neg       0.63      0.52      0.57       513
#          pos       0.89      0.93      0.91      2159
#
#    micro avg       0.85      0.85      0.85      2672
#    macro avg       0.76      0.73      0.74      2672
# weighted avg       0.84      0.85      0.84      2672

# %%
clfs = [LogisticRegression]
for clf in clfs:
    main(clf)
# Out:
# [0.87313433 0.86940299 0.87686567 0.87265918 0.88014981 0.88014981
#  0.8988764  0.90262172 0.8576779  0.86090226]
# Accurecy of LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False): 0.88 (+/- 0.03)
#               precision    recall  f1-score   support
#
#          neg       0.99      0.36      0.53       513
#          pos       0.87      1.00      0.93      2159
#
#    micro avg       0.88      0.88      0.88      2672
#    macro avg       0.93      0.68      0.73      2672
# weighted avg       0.89      0.88      0.85      2672

# %%
clfs = [SGDClassifier]
for clf in clfs:
    main(clf)
# Out:
# [0.95522388 0.92537313 0.95149254 0.93258427 0.93258427 0.9588015
#  0.94756554 0.94007491 0.92509363 0.94736842]
# Accurecy of SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#        early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=None,
#        n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='l2',
#        power_t=0.5, random_state=None, shuffle=True, tol=None,
#        validation_fraction=0.1, verbose=0, warm_start=False): 0.94 (+/- 0.02)
#               precision    recall  f1-score   support
#
#          neg       0.91      0.76      0.83       513
#          pos       0.94      0.98      0.96      2159
#
#    micro avg       0.94      0.94      0.94      2672
#    macro avg       0.93      0.87      0.90      2672
# weighted avg       0.94      0.94      0.94      2672

# %%
clfs = [SVC]
for clf in clfs:
    main(clf)
# Out:
# [0.80597015 0.80597015 0.80597015 0.80898876 0.80898876 0.80898876
#  0.80898876 0.80898876 0.80898876 0.80827068]
# Accurecy of SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False): 0.81 (+/- 0.00)
#               precision    recall  f1-score   support
#
#          neg       0.00      0.00      0.00       513
#          pos       0.81      1.00      0.89      2159
#
#    micro avg       0.81      0.81      0.81      2672
#    macro avg       0.40      0.50      0.45      2672
# weighted avg       0.65      0.81      0.72      2672
# C:\Users\Mohamed Fathy\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
clfs = [LinearSVC]
for clf in clfs:
    main(clf)
# Out:
# [0.94029851 0.92910448 0.95522388 0.94007491 0.92883895 0.95505618
#  0.94382022 0.93632959 0.93258427 0.94360902]
# Accurecy of LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0): 0.94 (+/- 0.02)
#               precision    recall  f1-score   support
#
#          neg       0.93      0.74      0.83       513
#          pos       0.94      0.99      0.96      2159
#
#    micro avg       0.94      0.94      0.94      2672
#    macro avg       0.94      0.87      0.90      2672
# weighted avg       0.94      0.94      0.94      2672

# %%
clfs = [DecisionTreeClassifier]
for clf in clfs:
    main(clf)
# Out:
# [0.83208955 0.87313433 0.84701493 0.86142322 0.87265918 0.88764045
#  0.84644195 0.8576779  0.85393258 0.85338346]
# Accurecy of DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'): 0.86 (+/- 0.03)
#               precision    recall  f1-score   support
#
#          neg       0.65      0.63      0.64       513
#          pos       0.91      0.92      0.92      2159
#
#    micro avg       0.86      0.86      0.86      2672
#    macro avg       0.78      0.78      0.78      2672
# weighted avg       0.86      0.86      0.86      2672

# %%
clfs = [RandomForestClassifier]
for clf in clfs:
    main(clf)
# Out:
# [0.89179104 0.87313433 0.87313433 0.88764045 0.89513109 0.88764045
#  0.89513109 0.87640449 0.88389513 0.88721805]
# Accurecy of RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False): 0.89 (+/- 0.02)
#               precision    recall  f1-score   support
#
#          neg       0.89      0.49      0.63       513
#          pos       0.89      0.99      0.94      2159
#
#    micro avg       0.89      0.89      0.89      2672
#    macro avg       0.89      0.74      0.78      2672
# weighted avg       0.89      0.89      0.88      2672
